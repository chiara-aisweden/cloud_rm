# %%
from src import *

# %% [markdown]
# # 🗺️ Major-TOM Filtering
# [![HF](https://img.shields.io/badge/%F0%9F%A4%97-Datasets-yellow)](https://www.huggingface.co/Major-TOM) [![paper](https://img.shields.io/badge/arXiv-2402.12095-D12424)](https://www.arxiv.org/abs/2402.12095) [![GitHub stars](https://img.shields.io/github/stars/ESA-PhiLab/Major-TOM?style=social&label=Star&maxAge=2592000)](https://github.com/ESA-PhiLab/Major-TOM/)
#
# This notebook demonstrates how to access MajorTOM-Core-S2L2A data quickly and filter a subset of interest.
#
# Examples:
# 1. Filtering based on location, time, and cloud cover
# 2. Downloading a filtered subset of the dataset
# 3. PyTorch Dataset with a local copy
# 4. HuggingFace `datasets` fast access via streaming

# %% [markdown]
# ### 1. 📅 Filtering based on location, time, and cloud cover
# First we will download a local copy of the dataset metadata, in this case from `Major-TOM/Core-S2L2a`

# %%
from pathlib import Path
import urllib.request

SOURCE_DATASET = 'Major-TOM/Core-S2L2A' # Identify HF Dataset
DATASET_DIR = Path('./data/Major-TOM/')
DATASET_DIR.mkdir(exist_ok=True, parents=True)
ACCESS_URL = 'https://huggingface.co/datasets/{}/resolve/main/metadata.parquet?download=true'.format(SOURCE_DATASET)
LOCAL_URL = DATASET_DIR / '{}.parquet'.format(ACCESS_URL.split('.parquet')[0].split('/')[-1])

# download from server to local url
gdf = metadata_from_url(ACCESS_URL, LOCAL_URL)

gdf.head()
# Out:
#    grid_cell  grid_row_u  grid_col_r  \
# 0  922D_249L        -922        -249
# 1  922D_245L        -922        -245
# 2  922D_244L        -922        -244
# 3  922D_243L        -922        -243
# 4  922D_242L        -922        -242
#
#                                           product_id           timestamp  \
# 0  S2A_MSIL2A_20230119T161811_N0509_R111_T01CDJ_2... 2023-01-19 16:18:11
# 1  S2B_MSIL2A_20181219T162339_N9999_R011_T01CEJ_2... 2018-12-19 16:23:39
# 2  S2A_MSIL2A_20200119T155811_N9999_R025_T01CEJ_2... 2020-01-19 15:58:11
# 3  S2A_MSIL2A_20210103T155811_N9999_R025_T01CEJ_2... 2021-01-03 15:58:11
# 4  S2B_MSIL2A_20181220T155319_N9999_R025_T01CEJ_2... 2018-12-20 15:53:19
#
#    cloud_cover  nodata  centre_lat  centre_lon         crs  \
# 0    18.941737     0.0  -82.770666 -178.200331  EPSG:32701
# 1    22.742201     0.0  -82.768451 -175.349546  EPSG:32701
# 2     0.000000     0.0  -82.767914 -174.636985  EPSG:32701
# 3     3.769691     0.0  -82.767385 -173.924477  EPSG:32701
# 4     0.000000     0.0  -82.766864 -173.212021  EPSG:32701
#
#                                          parquet_url  parquet_row  \
# 0  https://huggingface.co/datasets/Major-TOM/Core...            0
# 1  https://huggingface.co/datasets/Major-TOM/Core...            1
# 2  https://huggingface.co/datasets/Major-TOM/Core...            2
# 3  https://huggingface.co/datasets/Major-TOM/Core...            3
# 4  https://huggingface.co/datasets/Major-TOM/Core...            4
#
#                    geometry
# 0  POINT (-178.200 -82.771)
# 1  POINT (-175.350 -82.768)
# 2  POINT (-174.637 -82.768)
# 3  POINT (-173.924 -82.767)
# 4  POINT (-173.212 -82.767)

# %% [markdown]
# Then, we can specify a few regions using shapely geometry, for example:

# %%
from shapely.geometry import box

# Example bounding boxes used for filtering
switzerland = box(5.9559111595,45.8179931641,10.4920501709,47.808380127)
gabon = box(8.1283659854,-4.9213919841,15.1618722208,2.7923006325)
napoli = box(14.091710578,40.7915558593,14.3723765416,40.9819258062)
pacific = box(-153.3922893485,39.6170415622,-152.0423077748,40.7090892316) # a remote patch over pacific - no data

# %% [markdown]
# and then use it via our `filter_metadata` function - let's try to get some recent images around ⚽🍕 Napoli!

# %%
filtered_df = filter_metadata(gdf,
                              cloud_cover = (10,20), # cloud cover between 0% and 10%
                              region=gabon, # you can try with different bounding boxes, like in the cell above
                              daterange=('2020-01-01', '2020-02-01'), # temporal range
                              nodata=(0.0,0.0) # only 0% of no data allowed
                              )

filtered_df
# Out:
#        grid_cell  grid_row_u  grid_col_r  \
# 681506  39D_109R         -39         109
# 698808  29D_156R         -29         156
# 727390  12D_157R         -12         157
# 698775  29D_118R         -29         118
# 702178  27D_118R         -27         118
# 717237  18D_102R         -18         102
# 720603   16D_94R         -16          94
# 725664   13D_93R         -13          93
# 727330   12D_91R         -12          91
# 727333   12D_94R         -12          94
# 732321    9D_93R          -9          93
# 735593    7D_94R          -7          94
# 737226    6D_99R          -6          99
# 758809   8U_100R           8         100
# 746496   0U_159R           0         159
# 746505   0U_168R           0         168
# 758844   8U_155R           8         155
# 766703  13U_137R          13         137
# 766672   13U_99R          13          99
# 769824  15U_136R          15         136
# 766721  13U_157R          13         157
# 769844  15U_158R          15         158
# 779005  21U_150R          21         150
# 782007  23U_150R          23         150
# 778960   21U_94R          21          94
# 786449  26U_147R          26         147
# 787939  27U_150R          27         150
# 787938  27U_149R          27         149
# 787937  27U_148R          27         148
# 787936  27U_147R          27         147
# 789425  28U_156R          28         156
# 792415  30U_156R          30         156
#
#                                                product_id           timestamp  \
# 681506  S2B_MSIL2A_20200112T093249_N9999_R136_T32MNB_2... 2020-01-12 09:32:49
# 698808  S2A_MSIL2A_20200111T091341_N9999_R050_T33MUT_2... 2020-01-11 09:13:41
# 727390  S2A_MSIL2A_20200111T091341_N9999_R050_T33MVU_2... 2020-01-11 09:13:41
# 698775  S2B_MSIL2A_20200119T092219_N9999_R093_T32MPC_2... 2020-01-19 09:22:19
# 702178  S2B_MSIL2A_20200119T092219_N9999_R093_T32MPC_2... 2020-01-19 09:22:19
# 717237  S2B_MSIL2A_20200112T093249_N9999_R136_T32MND_2... 2020-01-12 09:32:49
# 720603  S2B_MSIL2A_20200112T093249_N9999_R136_T32MMD_2... 2020-01-12 09:32:49
# 725664  S2B_MSIL2A_20200112T093249_N9999_R136_T32MMD_2... 2020-01-12 09:32:49
# 727330  S2B_MSIL2A_20200115T094239_N9999_R036_T32MMD_2... 2020-01-15 09:42:39
# 727333  S2B_MSIL2A_20200112T093249_N9999_R136_T32MMD_2... 2020-01-12 09:32:49
# 732321  S2B_MSIL2A_20200112T093249_N9999_R136_T32MME_2... 2020-01-12 09:32:49
# 735593  S2B_MSIL2A_20200112T093249_N9999_R136_T32MME_2... 2020-01-12 09:32:49
# 737226  S2B_MSIL2A_20200112T093249_N9999_R136_T32MME_2... 2020-01-12 09:32:49
# 758809  S2B_MSIL2A_20200112T093249_N9999_R136_T32NMF_2... 2020-01-12 09:32:49
# 746496  S2A_MSIL2A_20200111T091341_N9999_R050_T33NVA_2... 2020-01-11 09:13:41
# 746505  S2A_MSIL2A_20200111T091341_N9999_R050_T33NWA_2... 2020-01-11 09:13:41
# 758844  S2A_MSIL2A_20200111T091341_N9999_R050_T33NUA_2... 2020-01-11 09:13:41
# 766703  S2A_MSIL2A_20200124T092251_N0500_R093_T33NTB_2... 2020-01-24 09:22:51
# 766672  S2B_MSIL2A_20200112T093249_N9999_R136_T32NMG_2... 2020-01-12 09:32:49
# 769824  S2A_MSIL2A_20200104T092401_N0500_R093_T32NRG_2... 2020-01-04 09:24:01
# 766721  S2A_MSIL2A_20200111T091341_N9999_R050_T33NVB_2... 2020-01-11 09:13:41
# 769844  S2A_MSIL2A_20200111T091341_N9999_R050_T33NVB_2... 2020-01-11 09:13:41
# 779005  S2A_MSIL2A_20200114T092331_N9999_R093_T33NUC_2... 2020-01-14 09:23:31
# 782007  S2A_MSIL2A_20200114T092331_N9999_R093_T33NUC_2... 2020-01-14 09:23:31
# 778960  S2B_MSIL2A_20200115T094239_N9999_R036_T32NMH_2... 2020-01-15 09:42:39
# 786449  S2A_MSIL2A_20200114T092331_N9999_R093_T33NUC_2... 2020-01-14 09:23:31
# 787939  S2A_MSIL2A_20200114T092331_N9999_R093_T33NUC_2... 2020-01-14 09:23:31
# 787938  S2A_MSIL2A_20200114T092331_N9999_R093_T33NUC_2... 2020-01-14 09:23:31
# 787937  S2A_MSIL2A_20200114T092331_N9999_R093_T33NUC_2... 2020-01-14 09:23:31
# 787936  S2A_MSIL2A_20200114T092331_N9999_R093_T33NUC_2... 2020-01-14 09:23:31
# 789425  S2A_MSIL2A_20200114T092331_N9999_R093_T33NUC_2... 2020-01-14 09:23:31
# 792415  S2A_MSIL2A_20200114T092331_N9999_R093_T33NUD_2... 2020-01-14 09:23:31
#
#         cloud_cover  nodata  centre_lat  centre_lon         crs  \
# 681506    19.800127     0.0   -3.457724    9.852520  EPSG:32732
# 698808    15.755674     0.0   -2.559595   14.070981  EPSG:32733
# 727390    17.481835     0.0   -1.032626   14.150264  EPSG:32733
# 698775    12.344208     0.0   -2.559515   10.654294  EPSG:32732
# 702178    17.022875     0.0   -2.379878   10.654292  EPSG:32732
# 717237    10.861949     0.0   -1.571526    9.211197  EPSG:32732
# 720603    13.178488     0.0   -1.391902    8.490177  EPSG:32732
# 725664    13.216625     0.0   -1.122441    8.400328  EPSG:32732
# 727330    16.824738     0.0   -1.032624    8.220641  EPSG:32732
# 727333    14.794797     0.0   -1.032618    8.490168  EPSG:32732
# 732321    12.917754     0.0   -0.763156    8.398235  EPSG:32732
# 735593    16.830086     0.0   -0.583512    8.488052  EPSG:32732
# 737226    15.712452     0.0   -0.493686    8.937152  EPSG:32732
# 758809    12.629754     0.0    0.763799    9.026973  EPSG:32632
# 746496    15.820726     0.0    0.045233   14.326367  EPSG:32633
# 746505    14.764375     0.0    0.045236   15.134754  EPSG:32633
# 758844    18.878088     0.0    0.763802   13.967075  EPSG:32633
# 766703    13.411869     0.0    1.212895   12.353311  EPSG:32633
# 766672    11.680712     0.0    1.212902    8.939377  EPSG:32632
# 769824    14.214237     0.0    1.392408   12.263552  EPSG:32632
# 766721    15.884639     0.0    1.212910   14.150240  EPSG:32633
# 769844    18.676356     0.0    1.392552   14.240086  EPSG:32633
# 779005    16.527269     0.0    1.931487   13.524684  EPSG:32633
# 782007    15.546140     0.0    2.111132   13.528051  EPSG:32633
# 778960    17.396004     0.0    1.931476    8.492272  EPSG:32632
# 786449    17.947545     0.0    2.380601   13.258376  EPSG:32633
# 787939    18.303139     0.0    2.470420   13.531423  EPSG:32633
# 787938    18.633573     0.0    2.470421   13.441508  EPSG:32633
# 787937    12.212087     0.0    2.470422   13.351593  EPSG:32633
# 787936    15.638808     0.0    2.470423   13.261677  EPSG:32633
# 789425    19.058428     0.0    2.560233   14.070912  EPSG:32633
# 792415    12.685688     0.0    2.739876   14.070916  EPSG:32633
#
#                                               parquet_url  parquet_row  \
# 681506  https://huggingface.co/datasets/Major-TOM/Core...           52
# 698808  https://huggingface.co/datasets/Major-TOM/Core...          354
# 727390  https://huggingface.co/datasets/Major-TOM/Core...          439
# 698775  https://huggingface.co/datasets/Major-TOM/Core...          321
# 702178  https://huggingface.co/datasets/Major-TOM/Core...          224
# 717237  https://huggingface.co/datasets/Major-TOM/Core...          285
# 720603  https://huggingface.co/datasets/Major-TOM/Core...          152
# 725664  https://huggingface.co/datasets/Major-TOM/Core...          213
# 727330  https://huggingface.co/datasets/Major-TOM/Core...          379
# 727333  https://huggingface.co/datasets/Major-TOM/Core...          382
# 732321  https://huggingface.co/datasets/Major-TOM/Core...          370
# 735593  https://huggingface.co/datasets/Major-TOM/Core...          142
# 737226  https://huggingface.co/datasets/Major-TOM/Core...          275
# 758809  https://huggingface.co/datasets/Major-TOM/Core...          358
# 746496  https://huggingface.co/datasets/Major-TOM/Core...           45
# 746505  https://huggingface.co/datasets/Major-TOM/Core...           54
# 758844  https://huggingface.co/datasets/Major-TOM/Core...          393
# 766703  https://huggingface.co/datasets/Major-TOM/Core...          252
# 766672  https://huggingface.co/datasets/Major-TOM/Core...          221
# 769824  https://huggingface.co/datasets/Major-TOM/Core...          373
# 766721  https://huggingface.co/datasets/Major-TOM/Core...          270
# 769844  https://huggingface.co/datasets/Major-TOM/Core...          393
# 779005  https://huggingface.co/datasets/Major-TOM/Core...           54
# 782007  https://huggingface.co/datasets/Major-TOM/Core...           56
# 778960  https://huggingface.co/datasets/Major-TOM/Core...            9
# 786449  https://huggingface.co/datasets/Major-TOM/Core...          498
# 787939  https://huggingface.co/datasets/Major-TOM/Core...          488
# 787938  https://huggingface.co/datasets/Major-TOM/Core...          487
# 787937  https://huggingface.co/datasets/Major-TOM/Core...          486
# 787936  https://huggingface.co/datasets/Major-TOM/Core...          485
# 789425  https://huggingface.co/datasets/Major-TOM/Core...          474
# 792415  https://huggingface.co/datasets/Major-TOM/Core...          464
#
#                      geometry
# 681506   POINT (9.853 -3.458)
# 698808  POINT (14.071 -2.560)
# 727390  POINT (14.150 -1.033)
# 698775  POINT (10.654 -2.560)
# 702178  POINT (10.654 -2.380)
# 717237   POINT (9.211 -1.572)
# 720603   POINT (8.490 -1.392)
# 725664   POINT (8.400 -1.122)
# 727330   POINT (8.221 -1.033)
# 727333   POINT (8.490 -1.033)
# 732321   POINT (8.398 -0.763)
# 735593   POINT (8.488 -0.584)
# 737226   POINT (8.937 -0.494)
# 758809    POINT (9.027 0.764)
# 746496   POINT (14.326 0.045)
# 746505   POINT (15.135 0.045)
# 758844   POINT (13.967 0.764)
# 766703   POINT (12.353 1.213)
# 766672    POINT (8.939 1.213)
# 769824   POINT (12.264 1.392)
# 766721   POINT (14.150 1.213)
# 769844   POINT (14.240 1.393)
# 779005   POINT (13.525 1.931)
# 782007   POINT (13.528 2.111)
# 778960    POINT (8.492 1.931)
# 786449   POINT (13.258 2.381)
# 787939   POINT (13.531 2.470)
# 787938   POINT (13.442 2.470)
# 787937   POINT (13.352 2.470)
# 787936   POINT (13.262 2.470)
# 789425   POINT (14.071 2.560)
# 792415   POINT (14.071 2.740)

# %% [markdown]
# Any row from the metadata can be very easily read into a `dict` of numpy arrays using our `read_row` function:

# %%
out = read_row(filtered_df.iloc[0], columns = ['B04', 'thumbnail'])
# Out:
# /home/edgelab/.local/lib/python3.10/site-packages/fsspec/parquet.py:223: UserWarning: Not enough data was used to sample the parquet footer. Try setting footer_sample_size >= 1330214.
#   warnings.warn(

# %% [markdown]
# ### 📩 Downloading a filtered subset of the dataset
#
# Use the `filter_download` function to download all files to the local directory at `local_dir`. Your new dataset will be named using `source_name`.
#
# More importantly, the `by_row` option allows to download specific rows from the archives. Set it to `True`, if you think you will take only a few files from each parquet file (most parquet files contain samples that are close to each other in space).
#
# If you expect to take most of the samples from the parquet file, setting `by_row` to `False` will probably be quicker (you then download the data as the entire file, before you rearrange it onto folders with only the files from your dataframe).

# %%
filter_download(filtered_df, local_dir='./data/', source_name='L2A', by_row=True)
# Out:
# Downloading and unpacking...:   0%|          | 0/20 [00:00<?, ?it/s]

# %% [markdown]
# You can now check your local directory for the local version of your dataset!

# %% [markdown]
# ### 🔥 PyTorch Dataset with a local copy
# We can use it directly with our `PyTorch` definition of the Dataset `MajorTOM`, just supply the metadata file and teh directory of the files:

# %%
ds = MajorTOM(filtered_df, './data/L2A')

ds[0]
# Out:
# {'meta': grid_cell                                               39D_109R
#  grid_row_u                                                   -39
#  grid_col_r                                                   109
#  product_id     S2B_MSIL2A_20200112T093249_N9999_R136_T32MNB_2...
#  timestamp                                    2020-01-12 09:32:49
#  cloud_cover                                            19.800127
#  nodata                                                       0.0
#  centre_lat                                             -3.457724
#  centre_lon                                               9.85252
#  crs                                                   EPSG:32732
#  parquet_url    https://huggingface.co/datasets/Major-TOM/Core...
#  parquet_row                                                   52
#  geometry            POINT (9.852519980516428 -3.457724119233589)
#  Name: 681506, dtype: object,
#  'B04': tensor([[[171, 174, 168,  ..., 133, 143, 151]],
#
#          [[174, 171, 176,  ..., 137, 137, 144]],
#
#          [[156, 170, 178,  ..., 134, 134, 141]],
#
#          ...,
#
#          [[158, 152, 146,  ..., 176, 169, 172]],
#
#          [[162, 151, 153,  ..., 168, 169, 167]],
#
#          [[162, 146, 152,  ..., 172, 169, 171]]], dtype=torch.int16),
#  'B03': tensor([[[212, 212, 220,  ..., 186, 181, 181]],
#
#          [[215, 223, 231,  ..., 187, 183, 187]],
#
#          [[223, 223, 211,  ..., 198, 182, 178]],
#
#          ...,
#
#          [[183, 195, 179,  ..., 216, 214, 211]],
#
#          [[190, 187, 180,  ..., 216, 208, 208]],
#
#          [[201, 209, 188,  ..., 203, 202, 206]]], dtype=torch.int16),
#  'B02': tensor([[[262, 271, 273,  ..., 240, 249, 261]],
#
#          [[264, 260, 271,  ..., 243, 235, 240]],
#
#          [[293, 271, 269,  ..., 253, 219, 215]],
#
#          ...,
#
#          [[248, 248, 241,  ..., 263, 248, 257]],
#
#          [[239, 225, 219,  ..., 253, 245, 262]],
#
#          [[225, 226, 235,  ..., 266, 280, 268]]], dtype=torch.int16),
#  'thumbnail': tensor([[[0.1098, 0.1098, 0.1098,  ..., 0.0980, 0.1020, 0.1020],
#           [0.1098, 0.1098, 0.1098,  ..., 0.1020, 0.1020, 0.1020],
#           [0.1098, 0.1098, 0.1098,  ..., 0.1020, 0.1020, 0.1020],
#           ...,
#           [0.0980, 0.0980, 0.0941,  ..., 0.1137, 0.1137, 0.1137],
#           [0.0980, 0.0980, 0.0941,  ..., 0.1137, 0.1137, 0.1098],
#           [0.0980, 0.0980, 0.0941,  ..., 0.1098, 0.1098, 0.1098]],
#
#          [[0.1294, 0.1294, 0.1294,  ..., 0.1176, 0.1216, 0.1216],
#           [0.1294, 0.1294, 0.1294,  ..., 0.1216, 0.1216, 0.1216],
#           [0.1294, 0.1294, 0.1294,  ..., 0.1216, 0.1216, 0.1216],
#           ...,
#           [0.1176, 0.1176, 0.1137,  ..., 0.1255, 0.1255, 0.1255],
#           [0.1176, 0.1176, 0.1137,  ..., 0.1255, 0.1255, 0.1216],
#           [0.1176, 0.1176, 0.1137,  ..., 0.1216, 0.1216, 0.1216]],
#
#          [[0.1451, 0.1451, 0.1451,  ..., 0.1294, 0.1333, 0.1333],
#           [0.1451, 0.1451, 0.1451,  ..., 0.1333, 0.1333, 0.1333],
#           [0.1451, 0.1451, 0.1451,  ..., 0.1333, 0.1333, 0.1333],
#           ...,
#           [0.1333, 0.1333, 0.1294,  ..., 0.1451, 0.1451, 0.1451],
#           [0.1333, 0.1333, 0.1294,  ..., 0.1451, 0.1451, 0.1412],
#           [0.1333, 0.1333, 0.1294,  ..., 0.1412, 0.1412, 0.1412]]])}

# %% [markdown]
# ### Ecco!

# %%
plt.imshow(np.stack(ds[14]['thumbnail'],-1))

# %% [markdown]
# ### HuggingFace `datasets` fast access via streaming
# First let's start with an example of very quick access *without* any filtering using HuggingFace `datasets` library with `streaming=True` functionality:

# %%
import datasets

ds = datasets.load_dataset('Major-TOM/Core-S2L2A', streaming=True)['train']
# Out:
# Resolving data files:   0%|          | 0/4492 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/4492 [00:00<?, ?it/s]

# %%
sample = next(iter(ds))

# %% [markdown]
# > Note that the first few thousand samples are near the South pole, so they tend to be quite bright! You can recover more information from the original tif files!

# %%
plot(sample)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Alternative: Filter by points : 🌋 MajorTOM-Volcano
# In case you are interested in retrieving all Major-TOM samples that contain specific points of interest, you can also use the `filter_metadata` in an alternative way.
#
# First, let's use an example data that contains multiple points with reference latitude and longitude coordinates (here, we focus on volcanoes):

# %%
import pandas as pd

# Volcano example database from plotly - hopefully you can still access the file at the time of use
query_df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/volcano_db.csv', encoding="ISO-8859-1")

query_df.head()
# Out:
#      Number     Volcano Name        Country         Region  Latitude  \
# 0  0803-001              Abu          Japan   Honshu-Japan    34.500
# 1  1505-096       Acamarachi          Chile        Chile-N   -23.300
# 2  1402-08=       Acatenango      Guatemala      Guatemala    14.501
# 3  0103-004  Acigol-Nevsehir         Turkey         Turkey    38.570
# 4  1201-04-            Adams  United States  US-Washington    46.206
#
#    Longitude    Elev            Type            Status Last Known
# 0    131.600   571.0  Shield volcano          Holocene    Unknown
# 1    -67.620  6046.0   Stratovolcano          Holocene    Unknown
# 2    -90.876  3976.0   Stratovolcano        Historical         D1
# 3     34.520  1689.0            Maar          Holocene          U
# 4   -121.490  3742.0   Stratovolcano  Tephrochronology         D6

# %% [markdown]
# We can easily build a reference object of the Major-TOM grid to **transform these coordinates** to cells in Major-TOM grid:

# %%
from src.grid import *

# This might take a few seconds to initialise!
MT_grid = Grid(10) # 10 is the 10 km grid, which we use by default

# %% [markdown]
# We can use `latlon2rowcol` method to get the Major-TOM grid coordinates, and then append this information to our `query_df`, to effectively turn it into a Major-TOM dataset:

# %%
# Get rows and cols
rows,cols = MT_grid.latlon2rowcol(query_df.Latitude.tolist(),
                                  query_df.Longitude.tolist())

# Combine into a string '[]U_[]R'
points = ['{}_{}'.format(i,j) for i, j in zip(rows,cols)]

query_df['grid_cell'] = points
query_df.head()
# Out:
#      Number     Volcano Name        Country         Region  Latitude  \
# 0  0803-001              Abu          Japan   Honshu-Japan    34.500
# 1  1505-096       Acamarachi          Chile        Chile-N   -23.300
# 2  1402-08=       Acatenango      Guatemala      Guatemala    14.501
# 3  0103-004  Acigol-Nevsehir         Turkey         Turkey    38.570
# 4  1201-04-            Adams  United States  US-Washington    46.206
#
#    Longitude    Elev            Type            Status Last Known   grid_cell
# 0    131.600   571.0  Shield volcano          Holocene    Unknown  384U_1207R
# 1    -67.620  6046.0   Stratovolcano          Holocene    Unknown   260D_692L
# 2    -90.876  3976.0   Stratovolcano        Historical         D1   161U_980L
# 3     34.520  1689.0            Maar          Holocene          U   429U_300R
# 4   -121.490  3742.0   Stratovolcano  Tephrochronology         D6   514U_937L

# %% [markdown]
# We can also filter the Major-TOM metadata file to reduce it only to the relevant samples:

# %%
filtered_df = gdf[gdf.grid_cell.isin(points)]
filtered_df.head()
# Out:
#        grid_cell  grid_row_u  grid_col_r  \
# 8582   874D_362R        -874         362
# 9066   872D_369R        -872         369
# 11252  864D_399R        -864         399
# 12276  860D_312L        -860        -312
# 13820  856D_412R        -856         412
#
#                                               product_id           timestamp  \
# 8582   S2B_MSIL2A_20211009T203629_N0500_R085_T58CDT_2... 2021-10-09 20:36:29
# 9066   S2B_MSIL2A_20190217T194529_N9999_R013_T58CDU_2... 2019-02-17 19:45:29
# 11252  S2B_MSIL2A_20221011T202619_N0400_R042_T58CEU_2... 2022-10-11 20:26:19
# 12276  S2B_MSIL2A_20191022T161349_N0500_R111_T09CWQ_2... 2019-10-22 16:13:49
# 13820  S2B_MSIL2A_20210201T203629_N0500_R085_T58CDV_2... 2021-02-01 20:36:29
#
#        cloud_cover    nodata  centre_lat  centre_lon         crs  \
# 8582      0.000000  0.000000  -78.459578  163.334896  EPSG:32758
# 9066      0.330872  0.043524  -78.279551  163.821772  EPSG:32758
# 11252     1.743081  0.000000  -77.558538  167.030580  EPSG:32758
# 12276    12.105567  0.000000  -77.199072 -126.720404  EPSG:32709
# 13820     0.000000  0.000000  -76.842900  163.192393  EPSG:32758
#
#                                              parquet_url  parquet_row  \
# 8582   https://huggingface.co/datasets/Major-TOM/Core...           82
# 9066   https://huggingface.co/datasets/Major-TOM/Core...           66
# 11252  https://huggingface.co/datasets/Major-TOM/Core...          252
# 12276  https://huggingface.co/datasets/Major-TOM/Core...          276
# 13820  https://huggingface.co/datasets/Major-TOM/Core...          320
#
#                        geometry
# 8582    POINT (163.335 -78.460)
# 9066    POINT (163.822 -78.280)
# 11252   POINT (167.031 -77.559)
# 12276  POINT (-126.720 -77.199)
# 13820   POINT (163.192 -76.843)

# %% [markdown]
# Finally, we can now explore some samples of interest, like below:

# %%
sample = query_df.iloc[0]

out = read_row(filtered_df[filtered_df.grid_cell==sample.grid_cell].iloc[0],
               columns = ['B04', 'thumbnail'])

print(sample)
out['thumbnail']
# Out:
# /home/edgelab/.local/lib/python3.10/site-packages/fsspec/parquet.py:223: UserWarning: Not enough data was used to sample the parquet footer. Try setting footer_sample_size >= 1033166.
#   warnings.warn(
# Number                0803-001
# Volcano Name               Abu
# Country                  Japan
# Region            Honshu-Japan
# Latitude                  34.5
# Longitude                131.6
# Elev                     571.0
# Type            Shield volcano
# Status                Holocene
# Last Known             Unknown
# grid_cell           384U_1207R
# Name: 0, dtype: object
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1068x1068>

# %% [markdown]
# ...and similarly to above, you can download a local copy of the Major-TOM dataset from a filtered dataframe:

# %%
filter_download(filtered_df, local_dir='./data/', source_name='L2A', by_row=True)
# Out:
# Downloading and unpacking...:   0%|          | 0/970 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 filter_download(filtered_df, local_dir='./data/', source_name='L2A', by_row=True)
#
# File ~/filip/SEEX30_Cloud_Fog/SEEX30_Cloud_Fog/Cloud_rm/major_tom/src/metadata_helpers.py:133, in filter_download(df, local_dir, source_name, by_row, verbose, tif_columns)
#     131 with pq.ParquetFile(temp_path) as pf:
#     132     for row_idx in rows:
# --> 133         table = pf.read_row_group(row_idx)
#     135         product_id = table['product_id'][0].as_py()
#     136         grid_cell = table['grid_cell'][0].as_py()
#
# File ~/.local/lib/python3.10/site-packages/pyarrow/parquet/core.py:468, in ParquetFile.read_row_group(self, i, columns, use_threads, use_pandas_metadata)
#     426 """
#     427 Read a single row group from a Parquet file.
#     428
#    (...)
#     464 animal: [["Flamingo","Parrot",...,"Brittle stars","Centipede"]]
#     465 """
#     466 column_indices = self._get_column_indices(
#     467     columns, use_pandas_metadata=use_pandas_metadata)
# --> 468 return self.reader.read_row_group(i, column_indices=column_indices,
#     469                                   use_threads=use_threads)
#
# File ~/.local/lib/python3.10/site-packages/pyarrow/_parquet.pyx:1608, in pyarrow._parquet.ParquetReader.read_row_group()
#
# File ~/.local/lib/python3.10/site-packages/pyarrow/_parquet.pyx:1644, in pyarrow._parquet.ParquetReader.read_row_groups()
#
# File ~/.local/lib/python3.10/site-packages/pyarrow/error.pxi:88, in pyarrow.lib.check_status()
#
# File ~/.local/lib/python3.10/site-packages/fsspec/implementations/http.py:595, in HTTPFile.read(self, length)
#     593 else:
#     594     length = min(self.size - self.loc, length)
# --> 595 return super().read(length)
#
# File ~/.local/lib/python3.10/site-packages/fsspec/spec.py:1846, in AbstractBufferedFile.read(self, length)
#    1843 if length == 0:
#    1844     # don't even bother calling fetch
#    1845     return b""
# -> 1846 out = self.cache._fetch(self.loc, self.loc + length)
#    1847 self.loc += len(out)
#    1848 return out
#
# File ~/.local/lib/python3.10/site-packages/fsspec/caching.py:439, in BytesCache._fetch(self, start, end)
#     437             self.start = start
#     438         else:
# --> 439             new = self.fetcher(self.end, bend)
#     440             self.cache = self.cache + new
#     442 self.end = self.start + len(self.cache)
#
# File ~/.local/lib/python3.10/site-packages/fsspec/asyn.py:118, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     115 @functools.wraps(func)
#     116 def wrapper(*args, **kwargs):
#     117     self = obj or args[0]
# --> 118     return sync(self.loop, func, *args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/fsspec/asyn.py:91, in sync(loop, func, timeout, *args, **kwargs)
#      88 asyncio.run_coroutine_threadsafe(_runner(event, coro, result, timeout), loop)
#      89 while True:
#      90     # this loops allows thread to get interrupted
# ---> 91     if event.wait(1):
#      92         break
#      93     if timeout is not None:
#
# File /usr/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File /usr/lib/python3.10/threading.py:324, in Condition.wait(self, timeout)
#     322 else:
#     323     if timeout > 0:
# --> 324         gotit = waiter.acquire(True, timeout)
#     325     else:
#     326         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
